# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafifkhalilgateng/Portofolio-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hari = "kamis"
match hari:
  case "senin":
   print("upacara")
  case "selasa":
   print("senam")
  case "rabu":
   print("literasi")
  case "kamis":
   print("kamisceria")
  case "jumat":
   print("imtaq")
  case "sabtu":
   print("libur")
  case "minggu":
   print("libur")
# Out:
# kamisceria
